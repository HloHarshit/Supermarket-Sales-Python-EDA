# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime as dt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(os.path.join(os.getcwd(), 'Data\supermarket_sales - Sheet1.csv'))
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Question 1: Display the shape of the dataset (total rows and total columns).

# %%
df.shape
# Out:
# (1000, 17)

# %%
print('Total number of rows:', len(df))
print('Total number of columns:', len(df.columns))
# Out:
# Total number of rows: 1000
# Total number of columns: 17

# %% [markdown]
# ## Question 2: Display the information about the dataset (total rows, total columns, datatypes of each columns and memory requirement).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ## Question 3: Get the overall statistics about the dataset.

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Question 1: Find aggregate sales among branches (categorical column).

# %%
df['Branch'].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
df['Branch'].value_counts().plot(kind='pie',autopct= '%1.2f%%')
plt.show()

# %%
sns.countplot(data=df, x='Branch')
plt.show()

# %% [markdown]
# ## Question 2: Find the most popular payment method used by customers (categorical column).

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
df['Payment'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Question 3: Find the distribution of the custoemer ratings (categorical column).

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
sns.distplot(df['Rating'])
plt.show()

# %% [markdown]
# ## Question 4: Find the distribution of the cost of goods sold (numerical column).

# %%
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.distplot(df['cogs'])
plt.show()

# %% [markdown]
# # Bivariate Analysis/Multivariate Analysis

# %% [markdown]
# ## Question 5: Does the cost of goods sold affect the ratings that the customers provided (numerical - numerical)?

# %%
sns.scatterplot(data=df, x='cogs', y='Rating')
plt.show()

# %% [markdown]
# ## Question 6: Does gross income affect the ratings that the customers provided (numerical - numerical)?

# %%
sns.scatterplot(data=df, x='gross income',y='Rating')
plt.show()

# %% [markdown]
# ## Question 7: Find the most profitable branch as per gross income (numerical - categorical).

# %%
sns.barplot(x=df['Branch'], y=df['gross income'], hue=df['City'], dodge=False)
plt.show()

# %% [markdown]
# ## Question 8: Is there any relationship between gender and gross income (categorical - numerical)?

# %%
sns.boxplot(data=df, x='Gender', y='gross income', hue='Customer type')
plt.show()

# %% [markdown]
# ## Question 9: Find the product line that generates the most income (categorical - numerical).

# %%
sns.barplot(data=df, x='Product line', y='gross income')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Question 10: Find the highest unit price in the product line (numerical - categorical).

# %%
sns.barplot(data=df, x='Product line', y='Unit price')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Question 11: Find different payment methods used by customers city wise (categorical - categorical).

# %%
pd.crosstab(df['City'], df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(df['City'], df['Payment']))
plt.show()

# %% [markdown]
# ## Question 12: Which product line is purchased in the highest quantity.

# %%
sns.barplot(data=df, x='Product line', y='Quantity')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Question 13: Display daily sales by day of the week.

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
dw_mapping = {
    0: 'Mon',
    1: 'Tue',
    2: 'Wed',
    3: 'Thu',
    4: 'Fri',
    5: 'Sat',
    6: 'Sun'
}

# %%
df['day_of_week'] = df['Date'].dt.dayofweek.map(dw_mapping)

# %%
df['day_of_week'].value_counts()
# Out:
# day_of_week
# Sat    164
# Tue    158
# Wed    143
# Fri    139
# Thu    138
# Sun    133
# Mon    125
# Name: count, dtype: int64

# %%
sns.countplot(x=df['day_of_week'])
plt.show()

# %% [markdown]
# ## Question 14: What will be the highest months for sales?

# %%
dm_mapping = {
    1: 'Jan',
    2: 'Feb',
    3: 'Mar',
    4: 'Apr',
    5: 'May',
    6: 'Jun',
    7: 'Jul',
    8: 'Aug',
    9: 'Sep',
    10: 'Oct',
    11: 'Nov',
    12: 'Dec'
}

# %%
df['Month'] = df['Date'].dt.month.map(dm_mapping)

# %%
df['Month'].value_counts()
# Out:
# Month
# Jan    352
# Mar    345
# Feb    303
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Month'])
plt.show()
